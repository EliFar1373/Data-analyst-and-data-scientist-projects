# %%
import pandas as pd
df_Hr=pd.read_csv(r"C:\Users\elham\Downloads\jobs\project2\HR_data.csv")
df_Ht=pd.read_csv(r"C:\Users\elham\Downloads\jobs\project2\hotel_data.csv")

# %%
from sqlalchemy import create_engine

username="root"
password="#"
port="3306"
database="data_project"
host="localhost"

engine=create_engine(f"mysql+pymysql://{username}:{password}@{host}:{port}/{database}")

df_Hr.to_sql("hr_data",con=engine,if_exists="replace",index=False)
df_Ht.to_sql("hotel_data",con=engine,if_exists="replace",index=False)
# Out:
# 119390
